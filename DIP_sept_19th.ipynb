# %%
pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('/content/WhatsApp Image 2024-09-04 at 8.21.50 PM.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
def display_image(title, img):
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
def translate_image(image, tx, ty):
    rows, cols = image.shape[:2]
    translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
    translated_image = cv2.warpAffine(image, translation_matrix, (cols, rows))
    return translated_image

# %%
def scale_image(image, scale_x, scale_y):
    scaled_image = cv2.resize(image, None, fx=scale_x, fy=scale_y)
    return scaled_image

# %%
def rotate_image(image, angle):
    rows, cols = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((cols/2, rows/2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (cols, rows))
    return rotated_image

# %%
def shrink_image(image, shrink_factor):
    return scale_image(image, 1/shrink_factor, 1/shrink_factor)

# %%
def zoom_image(image, zoom_factor):
    return scale_image(image, zoom_factor, zoom_factor)

# %%
display_image('Original Image', image)

# %%
translated_image = translate_image(image, 50, 100)  # Translate by 50 pixels in x, 100 in y
scaled_image = scale_image(image, 1.5, 1.5)         # Scale by 1.5x
rotated_image_45 = rotate_image(image, 45)          # Rotate by 45 degrees
rotated_image_100 = rotate_image(image, 100)        # Rotate by 100 degrees
rotated_image_125 = rotate_image(image, 125)        # Rotate by 125 degrees
rotated_image_270 = rotate_image(image, 270)        # Rotate by 270 degrees
shrunk_image = shrink_image(image, 2)               # Shrink by 2x
zoomed_image = zoom_image(image, 2)                 # Zoom by 2x

# %%
display_image('Translated Image', translated_image)
display_image('Scaled Image', scaled_image)
display_image('Rotated Image (45°)', rotated_image_45)
display_image('Rotated Image (100°)', rotated_image_100)
display_image('Rotated Image (125°)', rotated_image_125)
display_image('Rotated Image (270°)', rotated_image_270)
display_image('Shrunk Image', shrunk_image)
display_image('Zoomed Image', zoomed_image)
